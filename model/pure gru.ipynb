# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as k
import os
import Parameters as Para
para = Para.Parameters(epochs=50)
city = 'wulumuqi'

# %%
def get_correlation(a_list,b_list):
    return np.corrcoef(np.vstack((np.array(a_list),np.array(b_list))))

# %%
import getDataset as getDataset
input_data = list()
input_label = list()
# dataset_2016 = getDataset.GetDataset(year=2016, step=72, batch_size=64, data_size=data_size, predict_size=predict_size,split_rate=1)
dataset_2017 = getDataset.GetDataset(year=2017, step=48, batch_size=64, data_size=para.data_size, predict_size=para.predict_size,split_rate=1,city=city)
main_dataset = getDataset.GetDataset(year=2018, step=48, batch_size=64, data_size=para.data_size, predict_size=para.predict_size,split_rate=para.split_rate,city=city)
# data_mean_16, data_std_16 = train_dataset_2016.get_mean_std()
data_mean_17, data_std_17 = dataset_2017.get_mean_std()
data_mean, data_std = main_dataset.get_mean_std()
print(data_mean,data_std)
# Out:
# 56.35375118708452 57.827218130986495

# %%
# for data1, data2 in dataset_2016.train_dataset():
#     for var in data1:
#         input_data.append(var)
#     for var in data2:
#         input_label.append(var*data_std_16+data_mean_16)      
for data1, data2 in dataset_2017.train_dataset():
    for var in data1:
        input_data.append(var)
    for var in data2:
        input_label.append(var*data_std_17+data_mean_17)         
for data1, data2 in main_dataset.train_dataset():
    for var in data1:
        input_data.append(var)
    for var in data2:
        input_label.append(var*data_std+data_mean)

# %%
print(para.train_size,para.features)
current_data = np.reshape(np.array(input_data), (-1, para.train_size, para.features))
current_label = np.reshape(np.array(input_label), (-1, para.predict_size, 1))

validate_data = list()
validate_label = list()
count = 0
for data1, data2 in main_dataset.test_dataset():
    if count<para.validate_num:
        for var in data1:
            validate_data.append(var)
        for var in data2:
            validate_label.append(var*data_std+data_mean)
    else:
        break
    count+=1
validate_data = np.reshape(np.array(validate_data), (-1, para.train_size, para.features))
validate_label = np.reshape(np.array(validate_label), (-1, para.predict_size, 1))
# Out:
# 72 15

# %%
inputs = tf.keras.Input(shape=(para.train_size, para.features))
x_input = tf.keras.layers.BatchNormalization(input_shape=(para.train_size,para.features))(inputs)
output_ = tf.keras.layers.LSTM(units=para.node_size)(x_input)
output_ = tf.keras.layers.Dense(units=para.predict_size)(output_)
autoEncoder = tf.keras.Model(inputs=inputs, outputs=output_)
autoEncoder.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.mean_absolute_error,
                    metrics=[tf.keras.metrics.mean_absolute_percentage_error])
# checkpoint = tf.keras.callbacks.ModelCheckpoint('D:/python_enviroments/Tensorflow_New_Enviroment/paper/checkpoint', monitor='val_acc', verbose=0, save_best_only=False, mode='min', period=5)
# log_dir = 'D:/python_enviroments/Tensorflow_New_Enviroment/paper/log'
# tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
# callback_lists=[checkpoint]
autoEncoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 72, 15)]          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 72, 15)            60
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                6144
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                792
# =================================================================
# Total params: 6,996
# Trainable params: 6,966
# Non-trainable params: 30
# _________________________________________________________________

# %%
# 100轮
autoEncoder.fit(epochs=para.epochs,x= tf.convert_to_tensor(current_data,dtype=tf.float32), y=tf.convert_to_tensor(current_label,tf.float32), validation_data=[validate_data,validate_label],  batch_size=64)#,callbacks=callback_lists)
# Out:
# Train on 11008 samples, validate on 15 samples
# Epoch 1/50
# 11008/11008 [==============================] - 3s 288us/sample - loss: 38.8087 - mean_absolute_percentage_error: 84.1742 - val_loss: 17.0780 - val_mean_absolute_percentage_error: 60.5660
# Epoch 2/50
# 11008/11008 [==============================] - 1s 103us/sample - loss: 31.6349 - mean_absolute_percentage_error: 56.3202 - val_loss: 12.5246 - val_mean_absolute_percentage_error: 47.4617
# Epoch 3/50
# 11008/11008 [==============================] - 1s 104us/sample - loss: 27.7308 - mean_absolute_percentage_error: 46.0614 - val_loss: 10.1800 - val_mean_absolute_percentage_error: 45.1435
# Epoch 4/50
# 11008/11008 [==============================] - 1s 102us/sample - loss: 25.9416 - mean_absolute_percentage_error: 45.0224 - val_loss: 9.2138 - val_mean_absolute_percentage_error: 47.0181
# Epoch 5/50
# 11008/11008 [==============================] - 1s 103us/sample - loss: 25.2098 - mean_absolute_percentage_error: 46.5688 - val_loss: 8.8092 - val_mean_absolute_percentage_error: 49.3009
# Epoch 6/50
# 11008/11008 [==============================] - 1s 103us/sample - loss: 24.9388 - mean_absolute_percentage_error: 48.2706 - val_loss: 8.6512 - val_mean_absolute_percentage_error: 50.9090
# Epoch 7/50
# 11008/11008 [==============================] - 1s 103us/sample - loss: 24.6907 - mean_absolute_percentage_error: 47.9570 - val_loss: 8.1907 - val_mean_absolute_percentage_error: 48.9225
# Epoch 8/50
# 11008/11008 [==============================] - 1s 102us/sample - loss: 23.5346 - mean_absolute_percentage_error: 41.5235 - val_loss: 7.7681 - val_mean_absolute_percentage_error: 48.4366
# Epoch 9/50
# 11008/11008 [==============================] - 1s 105us/sample - loss: 22.6452 - mean_absolute_percentage_error: 39.7240 - val_loss: 8.1207 - val_mean_absolute_percentage_error: 52.0921
# Epoch 10/50
# 11008/11008 [==============================] - 1s 104us/sample - loss: 21.9497 - mean_absolute_percentage_error: 38.5808 - val_loss: 8.5620 - val_mean_absolute_percentage_error: 55.5498
# Epoch 11/50
# 11008/11008 [==============================] - 1s 105us/sample - loss: 21.2873 - mean_absolute_percentage_error: 37.2443 - val_loss: 8.5644 - val_mean_absolute_percentage_error: 55.6889
# Epoch 12/50
# 11008/11008 [==============================] - 1s 109us/sample - loss: 20.6414 - mean_absolute_percentage_error: 35.8567 - val_loss: 8.5128 - val_mean_absolute_percentage_error: 56.2115
# Epoch 13/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 20.0611 - mean_absolute_percentage_error: 35.0937 - val_loss: 8.8628 - val_mean_absolute_percentage_error: 58.9623
# Epoch 14/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 19.5092 - mean_absolute_percentage_error: 34.1684 - val_loss: 9.0844 - val_mean_absolute_percentage_error: 60.5127
# Epoch 15/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 19.0659 - mean_absolute_percentage_error: 33.5434 - val_loss: 9.7253 - val_mean_absolute_percentage_error: 62.0147
# Epoch 16/50
# 11008/11008 [==============================] - 1s 112us/sample - loss: 18.6615 - mean_absolute_percentage_error: 32.9985 - val_loss: 9.7225 - val_mean_absolute_percentage_error: 65.8578
# Epoch 17/50
# 11008/11008 [==============================] - 1s 112us/sample - loss: 18.1974 - mean_absolute_percentage_error: 32.0194 - val_loss: 10.0128 - val_mean_absolute_percentage_error: 68.5358
# Epoch 18/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 17.7907 - mean_absolute_percentage_error: 31.2932 - val_loss: 10.0980 - val_mean_absolute_percentage_error: 68.6238
# Epoch 19/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 17.3272 - mean_absolute_percentage_error: 30.4710 - val_loss: 10.3069 - val_mean_absolute_percentage_error: 70.1436
# Epoch 20/50
# 11008/11008 [==============================] - 1s 121us/sample - loss: 16.9811 - mean_absolute_percentage_error: 30.0581 - val_loss: 10.4732 - val_mean_absolute_percentage_error: 71.3668
# Epoch 21/50
# 11008/11008 [==============================] - 1s 121us/sample - loss: 16.5935 - mean_absolute_percentage_error: 29.5210 - val_loss: 11.1848 - val_mean_absolute_percentage_error: 75.3892
# Epoch 22/50
# 11008/11008 [==============================] - 1s 122us/sample - loss: 16.2581 - mean_absolute_percentage_error: 29.0975 - val_loss: 10.2577 - val_mean_absolute_percentage_error: 74.2454
# Epoch 23/50
# 11008/11008 [==============================] - 1s 119us/sample - loss: 16.1314 - mean_absolute_percentage_error: 29.1170 - val_loss: 12.0805 - val_mean_absolute_percentage_error: 85.7610
# Epoch 24/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 15.7222 - mean_absolute_percentage_error: 28.6714 - val_loss: 11.6633 - val_mean_absolute_percentage_error: 84.2736
# Epoch 25/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 15.3736 - mean_absolute_percentage_error: 28.1192 - val_loss: 12.4843 - val_mean_absolute_percentage_error: 89.1633
# Epoch 26/50
# 11008/11008 [==============================] - 1s 120us/sample - loss: 15.0986 - mean_absolute_percentage_error: 27.7218 - val_loss: 12.3389 - val_mean_absolute_percentage_error: 90.2593
# Epoch 27/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 14.9338 - mean_absolute_percentage_error: 27.9060 - val_loss: 12.2877 - val_mean_absolute_percentage_error: 90.1732
# Epoch 28/50
# 11008/11008 [==============================] - 1s 117us/sample - loss: 14.6217 - mean_absolute_percentage_error: 27.2053 - val_loss: 12.3415 - val_mean_absolute_percentage_error: 91.7717
# Epoch 29/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 14.4265 - mean_absolute_percentage_error: 27.1255 - val_loss: 12.3701 - val_mean_absolute_percentage_error: 93.5239
# Epoch 30/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 14.1471 - mean_absolute_percentage_error: 26.6823 - val_loss: 12.5594 - val_mean_absolute_percentage_error: 95.1144
# Epoch 31/50
# 11008/11008 [==============================] - 1s 120us/sample - loss: 14.0649 - mean_absolute_percentage_error: 26.6014 - val_loss: 13.8641 - val_mean_absolute_percentage_error: 98.4830
# Epoch 32/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 13.9240 - mean_absolute_percentage_error: 26.8365 - val_loss: 12.8390 - val_mean_absolute_percentage_error: 98.5370
# Epoch 33/50
# 11008/11008 [==============================] - 1s 117us/sample - loss: 13.6432 - mean_absolute_percentage_error: 26.3519 - val_loss: 12.9396 - val_mean_absolute_percentage_error: 96.9612
# Epoch 34/50
# 11008/11008 [==============================] - 1s 114us/sample - loss: 13.5518 - mean_absolute_percentage_error: 26.3311 - val_loss: 13.2376 - val_mean_absolute_percentage_error: 100.3546
# Epoch 35/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 13.3573 - mean_absolute_percentage_error: 26.0354 - val_loss: 12.3118 - val_mean_absolute_percentage_error: 92.7701
# Epoch 36/50
# 11008/11008 [==============================] - 1s 117us/sample - loss: 13.1773 - mean_absolute_percentage_error: 25.7438 - val_loss: 12.8579 - val_mean_absolute_percentage_error: 99.6334
# Epoch 37/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 13.1516 - mean_absolute_percentage_error: 25.9429 - val_loss: 12.5869 - val_mean_absolute_percentage_error: 98.7174
# Epoch 38/50
# 11008/11008 [==============================] - 1s 118us/sample - loss: 12.8876 - mean_absolute_percentage_error: 25.3893 - val_loss: 12.3414 - val_mean_absolute_percentage_error: 95.4703
# Epoch 39/50
# 11008/11008 [==============================] - 1s 119us/sample - loss: 12.7264 - mean_absolute_percentage_error: 25.1908 - val_loss: 12.2445 - val_mean_absolute_percentage_error: 95.5089
# Epoch 40/50
# 11008/11008 [==============================] - 1s 117us/sample - loss: 12.6049 - mean_absolute_percentage_error: 25.1151 - val_loss: 12.5327 - val_mean_absolute_percentage_error: 96.7782
# Epoch 41/50
# 11008/11008 [==============================] - 1s 113us/sample - loss: 12.6098 - mean_absolute_percentage_error: 25.0686 - val_loss: 12.4968 - val_mean_absolute_percentage_error: 96.7414
# Epoch 42/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 12.4287 - mean_absolute_percentage_error: 24.8657 - val_loss: 12.7268 - val_mean_absolute_percentage_error: 97.8975
# Epoch 43/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 12.4229 - mean_absolute_percentage_error: 25.1559 - val_loss: 12.8308 - val_mean_absolute_percentage_error: 99.2098
# Epoch 44/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 12.1818 - mean_absolute_percentage_error: 24.6430 - val_loss: 14.3395 - val_mean_absolute_percentage_error: 106.8320
# Epoch 45/50
# 11008/11008 [==============================] - 1s 113us/sample - loss: 12.1079 - mean_absolute_percentage_error: 24.6901 - val_loss: 12.9698 - val_mean_absolute_percentage_error: 99.2195
# Epoch 46/50
# 11008/11008 [==============================] - 1s 114us/sample - loss: 11.9396 - mean_absolute_percentage_error: 24.3200 - val_loss: 13.1880 - val_mean_absolute_percentage_error: 100.4000
# Epoch 47/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 11.8889 - mean_absolute_percentage_error: 24.3596 - val_loss: 13.2214 - val_mean_absolute_percentage_error: 100.2358
# Epoch 48/50
# 11008/11008 [==============================] - 1s 115us/sample - loss: 11.7545 - mean_absolute_percentage_error: 24.1302 - val_loss: 13.1053 - val_mean_absolute_percentage_error: 98.7982
# Epoch 49/50
# 11008/11008 [==============================] - 1s 116us/sample - loss: 11.6177 - mean_absolute_percentage_error: 23.9479 - val_loss: 13.2356 - val_mean_absolute_percentage_error: 100.0379
# Epoch 50/50
# 11008/11008 [==============================] - 1s 114us/sample - loss: 11.5052 - mean_absolute_percentage_error: 23.7379 - val_loss: 13.3077 - val_mean_absolute_percentage_error: 100.2696

# %%
import matplotlib.pyplot as plt
result_dir = "D:/python_enviroments/Tensorflow_New_Enviroment/paper/论文实验部分/Result/"+city+"/"
file_name = "Pure LSTM"
import matplotlib.pyplot as plt
# 连续化的对比图
final_data = main_dataset.final_data(para.validate_num)
real = final_data[para.train_size:].T[1].T
predict = list()
for index_var in range(para.validate_num):
    y = autoEncoder.predict(x=np.reshape(final_data[para.predict_size*index_var:para.predict_size*index_var+para.train_size],(-1,para.train_size,para.features)))
    y = np.reshape(y,(-1,))
    predict.append(y)
predict = np.reshape(np.array(predict),(-1,))
print(get_correlation(predict,real))
plt.plot(np.arange(0,len(predict)),predict,linewidth= 1,color = 'r', marker = '^',markersize=1)
plt.plot(np.arange(0,len(real)),real*data_std+data_mean,linewidth= 1,color = 'b', marker = 'o',markersize=1)
plt.xlabel('hour')
plt.ylabel('PM2.5')
plt.legend(['predict','real'])
plt.savefig(result_dir+str(para.node_size)+ file_name+' prediction.png')
# Out:
# [[1.         0.46790999]
#  [0.46790999 1.        ]]

# %%
# 设置checkpoint  
plt.plot(np.arange(0,len(autoEncoder.history.history['loss'])),autoEncoder.history.history['loss'],marker = 'o',linewidth = 1,markersize = 4)
plt.plot(np.arange(0,len(autoEncoder.history.history['val_loss'])),autoEncoder.history.history['val_loss'],marker = '^', linewidth = 1,markersize = 4)
plt.xlabel('epochs')
plt.ylabel('Mae')
plt.legend(['train', 'test'])
plt.savefig(result_dir+str(para.node_size)+ file_name+' loss.png')
