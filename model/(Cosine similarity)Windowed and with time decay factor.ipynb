# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as k
import os
import Parameters as Para
para = Para.Parameters()

# %%
def get_correlation(a_list,b_list):
    return np.corrcoef(np.vstack((np.array(a_list),np.array(b_list))))

# %%
import getDataset as getDataset
input_data = list()
input_label = list()
# dataset_2016 = getDataset.GetDataset(year=2016, step=72, batch_size=64, data_size=data_size, predict_size=predict_size,split_rate=1)
dataset_2017 = getDataset.GetDataset(year=2017, step=48, batch_size=64, data_size=para.data_size, predict_size=para.predict_size,split_rate=1)
main_dataset = getDataset.GetDataset(year=2018, step=48, batch_size=64, data_size=para.data_size, predict_size=para.predict_size,split_rate=para.split_rate)
# data_mean_16, data_std_16 = train_dataset_2016.get_mean_std()
data_mean_17, data_std_17 = dataset_2017.get_mean_std()
data_mean, data_std = main_dataset.get_mean_std()
print(data_mean,data_std)
# Out:
# 35.96626420454545 28.853002002441322

# %%
# for data1, data2 in dataset_2016.train_dataset():
#     for var in data1:
#         input_data.append(var)
#     for var in data2:
#         input_label.append(var*data_std_16+data_mean_16)      
for data1, data2 in dataset_2017.train_dataset():
    for var in data1:
        input_data.append(var)
    for var in data2:
        input_label.append(var*data_std_17+data_mean_17)         
for data1, data2 in main_dataset.train_dataset():
    for var in data1:
        input_data.append(var)
    for var in data2:
        input_label.append(var*data_std+data_mean)

# %%
print(para.train_size,para.features)
current_data = np.reshape(np.array(input_data), (-1, para.train_size, para.features))
current_label = np.reshape(np.array(input_label), (-1, para.predict_size, 1))

validate_data = list()
validate_label = list()
count = 0
for data1, data2 in main_dataset.test_dataset():
    if count<para.validate_num:
        for var in data1:
            validate_data.append(var)
        for var in data2:
            validate_label.append(var*data_std+data_mean)
    else:
        break
    count+=1
validate_data = np.reshape(np.array(validate_data), (-1, para.train_size, para.features))
validate_label = np.reshape(np.array(validate_label), (-1, para.predict_size, 1))
# Out:
# 72 15

# %%
class Attention(k.layers.Layer):
    def __init__(self, units):
        super(Attention, self).__init__()
        self.W1 = k.layers.Dense(units,kernel_initializer='glorot_uniform',kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),use_bias=False)
        self.W2 = k.layers.Dense(units,kernel_initializer='glorot_uniform',kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),use_bias=False)
        self.V = k.layers.Dense(1,kernel_initializer='glorot_uniform',kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),use_bias=False)
    def call(self, inputs, values = None, time = None):
        time_rate = []
        for i in range(time):
            time_rate.append(i+1/time)
        time_rate = tf.convert_to_tensor(time_rate,dtype=tf.float32)
        time_rate = tf.expand_dims(tf.nn.softmax(time_rate),axis=1)
        # values*=time_rate
        hidden_with_time_axis = tf.expand_dims(inputs,axis=1)
        pooled_len_1 = tf.sqrt(tf.reduce_sum(hidden_with_time_axis * hidden_with_time_axis, axis = 1))
        pooled_len_2 = tf.sqrt(tf.reduce_sum(values * values, axis = 1))
        pooled_mul_12 = tf.reduce_sum(hidden_with_time_axis * values, axis = 1)
        score = tf.expand_dims(pooled_mul_12 / (pooled_len_1 * pooled_len_2 +1e-10),axis=1)
        pollutant_vector = score*values*time_rate
        pollutant_vector = tf.reduce_mean(pollutant_vector, axis=1)
        return pollutant_vector

# %%
class Encoder(k.Model):
    def __init__(self,encoder_units):
        """
        :param encoder_units: 
        """
        super(Encoder, self).__init__()
        self.encoder_units = encoder_units
        self.encoder = k.layers.LSTM(self.encoder_units,
                                return_sequences=True,
                                return_state=True,
                                     kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),
                                     name = 'encoder')

    def call(self, inputs, training=None, mask=None):
        # enc_output, enc_h_state_input, enc_c_state_input = tf.keras.layers.Bidirectional(self.encoder(inputs))
        output,enc_h_state_input,enc_c_state_input= self.encoder(inputs)
        # 给解码器的隐藏状态和细胞状态赋初值
        attention_values = output
        dec_h_state_input = tf.zeros(tf.shape(enc_h_state_input))
        return attention_values, enc_c_state_input, dec_h_state_input
    
class Decoder(k.Model):
    def __init__(self,decoder_units, predict_size, time_size):
        """
        :param decoder_units: 
        :param predict_size: 
        :param time_size: 
        """
        super(Decoder, self).__init__()
        self.predict_size = predict_size
        self.decoder_units = decoder_units
        self.time_size = time_size
        self.decoder = k.layers.LSTM(self.decoder_units,
                                     return_sequences=True,
                                return_state=True,
                                     kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),
                                     name = 'decoder')   
        self.dec_fc = k.layers.Dense(para.features,kernel_initializer='glorot_uniform',
                                     kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),name = 'output')
        self.output_fc = k.layers.Dense(decoder_units,kernel_initializer='glorot_uniform',
                                     kernel_regularizer=tf.keras.regularizers.l2(para.l2_rate),name = 'output')
        self.h_attention_feature = Attention(para.features)
    def call(self, inputs, attention_values = None, dec_c_state_input = None, dec_h_state_input = None, training=None, mask=None):
        # 获得编码器隐藏状态，编码器细胞状态
        # 编码器的所有输出
        dec_output_list_13 = list()
        # 用全0向量初始化
        # input_value = tf.zeros(shape = tf.shape(inputs[:,-1:,:]))
        input_value = inputs[:,-1:,:]
        for step in range(self.predict_size):
            dec_output, dec_h_state_input, dec_c_state_input = self.decoder(initial_state=[dec_h_state_input,dec_c_state_input],inputs = input_value)
            dec_c_state_input = tf.concat([dec_c_state_input,self.h_attention_feature(inputs = dec_h_state_input, values = attention_values,time = para.data_size-para.predict_size+step)],axis=-1)
            dec_c_state_input = self.output_fc(dec_c_state_input)
            attention_values = tf.concat([dec_output,attention_values],axis=1)
            input_value = self.dec_fc(dec_output)
            # output_value = self.output_fc(dec_output)
            dec_output_list_13.append(input_value[:,:,1:2]*data_std+data_mean)
        dec_output_list_13 = tf.transpose(tf.squeeze(tf.convert_to_tensor(dec_output_list_13),axis=2),[1,0,2])
        return dec_output_list_13

# %%
# seq_to_seq_sample = SeqToSeq(encoder_units=32, decoder_units=32, predict_size=predict_size, time_size = data_size)
encoder = Encoder(encoder_units=para.node_size)
decoder = Decoder(decoder_units=para.node_size, predict_size=para.predict_size, time_size = para.data_size)
inputs = tf.keras.Input(shape=(para.train_size, para.features))
x_input = tf.keras.layers.BatchNormalization(input_shape=(para.train_size,para.features))(inputs)
a_values, c_state, h_state = encoder(x_input)
output_ = decoder(x_input, a_values,  c_state, h_state)
autoEncoder = tf.keras.Model(inputs=inputs, outputs=output_)
autoEncoder.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.mean_absolute_error,
                    metrics=[tf.keras.metrics.mean_absolute_percentage_error])
# checkpoint = tf.keras.callbacks.ModelCheckpoint('D:/python_enviroments/Tensorflow_New_Enviroment/paper/checkpoint', monitor='val_acc', verbose=0, save_best_only=False, mode='min', period=5)
# log_dir = 'D:/python_enviroments/Tensorflow_New_Enviroment/paper/log'
# tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
# callback_lists=[checkpoint]
autoEncoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 72, 15)]          0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 72, 15)            60
# _________________________________________________________________
# encoder (Encoder)            ((None, 72, 32), (None, 3 6144
# _________________________________________________________________
# decoder (Decoder)            (None, 24, 1)             8719
# =================================================================
# Total params: 14,923
# Trainable params: 14,893
# Non-trainable params: 30
# _________________________________________________________________

# %%
# 100轮
autoEncoder.fit(epochs=para.epochs,x= tf.convert_to_tensor(current_data,dtype=tf.float32), y=tf.convert_to_tensor(current_label,tf.float32), validation_data=[validate_data,validate_label],  batch_size=64)#,callbacks=callback_lists)
# Out:
# Train on 11008 samples, validate on 15 samples
# Epoch 1/50
# 11008/11008 [==============================] - 146s 13ms/sample - loss: 16.4234 - mean_absolute_percentage_error: 41.4522 - val_loss: 11.0190 - val_mean_absolute_percentage_error: 47.8555
# Epoch 2/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 12.1236 - mean_absolute_percentage_error: 30.9717 - val_loss: 10.9072 - val_mean_absolute_percentage_error: 47.9345
# Epoch 3/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 10.8669 - mean_absolute_percentage_error: 28.7975 - val_loss: 11.6221 - val_mean_absolute_percentage_error: 57.6106
# Epoch 4/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 10.7792 - mean_absolute_percentage_error: 28.9704 - val_loss: 11.2190 - val_mean_absolute_percentage_error: 51.6252
# Epoch 5/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 9.8902 - mean_absolute_percentage_error: 25.5786 - val_loss: 11.7925 - val_mean_absolute_percentage_error: 57.1619
# Epoch 6/50
#  - ETA: 22s - loss: 9.6711 - mean_absolute_percentage_error: 24.2907
# Epoch 7/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 11.4085 - mean_absolute_percentage_error: 29.8217 - val_loss: 11.9321 - val_mean_absolute_percentage_error: 57.7138
# Epoch 8/50
#  - ETA: 22s - loss: 10.2804 - mean_absolute_percentage_error: 26.5604
# Epoch 9/50
#  - ETA: 3s - loss: 9.4371 - mean_absolute_percentage_error: 24.2178
# Epoch 10/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 9.1641 - mean_absolute_percentage_error: 23.3596 - val_loss: 12.6945 - val_mean_absolute_percentage_error: 68.5982
# Epoch 11/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 9.3796 - mean_absolute_percentage_error: 24.4309 - val_loss: 12.1564 - val_mean_absolute_percentage_error: 63.1091
# Epoch 12/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 8.7858 - mean_absolute_percentage_error: 22.2754 - val_loss: 12.4373 - val_mean_absolute_percentage_error: 65.9103
# Epoch 13/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 8.6343 - mean_absolute_percentage_error: 21.8919 - val_loss: 11.2310 - val_mean_absolute_percentage_error: 58.6471
# Epoch 14/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 8.4308 - mean_absolute_percentage_error: 21.3624 - val_loss: 11.9179 - val_mean_absolute_percentage_error: 62.2670
# Epoch 15/50
#  - ETA: 6s - loss: 8.5108 - mean_absolute_percentage_error: 21.5992
# Epoch 16/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 8.1993 - mean_absolute_percentage_error: 20.7196 - val_loss: 10.8149 - val_mean_absolute_percentage_error: 55.1264
# Epoch 17/50
#  - ETA: 12s - loss: 8.1909 - mean_absolute_percentage_error: 20.6987
# Epoch 18/50
# 11008/11008 [==============================] - 38s 3ms/sample - loss: 8.2009 - mean_absolute_percentage_error: 20.8340 - val_loss: 11.1236 - val_mean_absolute_percentage_error: 58.0544
# Epoch 19/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 7.9285 - mean_absolute_percentage_error: 20.0233 - val_loss: 12.2063 - val_mean_absolute_percentage_error: 60.9145
# Epoch 20/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 13.9057 - mean_absolute_percentage_error: 37.1921 - val_loss: 14.1519 - val_mean_absolute_percentage_error: 75.5707
# Epoch 21/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 10.4375 - mean_absolute_percentage_error: 27.3407 - val_loss: 12.2425 - val_mean_absolute_percentage_error: 57.1080
# Epoch 22/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 9.2948 - mean_absolute_percentage_error: 24.2567 - val_loss: 11.4846 - val_mean_absolute_percentage_error: 56.6651
# Epoch 23/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 14.9641 - mean_absolute_percentage_error: 41.0773 - val_loss: 12.0426 - val_mean_absolute_percentage_error: 63.0542
# Epoch 24/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 10.6369 - mean_absolute_percentage_error: 27.9326 - val_loss: 12.8393 - val_mean_absolute_percentage_error: 67.6281
# Epoch 25/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 9.5315 - mean_absolute_percentage_error: 24.9469 - val_loss: 12.8920 - val_mean_absolute_percentage_error: 68.8696
# Epoch 26/50
#  - ETA: 12s - loss: 8.9954 - mean_absolute_percentage_error: 23.2262
# Epoch 27/50
#  - ETA: 3s - loss: 10.6897 - mean_absolute_percentage_error: 27.0743
# Epoch 28/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 8.5694 - mean_absolute_percentage_error: 22.1661 - val_loss: 11.9256 - val_mean_absolute_percentage_error: 63.8834
# Epoch 29/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 8.4666 - mean_absolute_percentage_error: 21.9623 - val_loss: 12.7939 - val_mean_absolute_percentage_error: 73.1410
# Epoch 30/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 8.1264 - mean_absolute_percentage_error: 20.9403 - val_loss: 11.3392 - val_mean_absolute_percentage_error: 63.6124
# Epoch 31/50
#  - ETA: 12s - loss: 7.9999 - mean_absolute_percentage_error: 20.6460
# Epoch 32/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 7.6752 - mean_absolute_percentage_error: 19.8540 - val_loss: 10.5887 - val_mean_absolute_percentage_error: 57.3498
# Epoch 33/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 7.6068 - mean_absolute_percentage_error: 19.6571 - val_loss: 10.4420 - val_mean_absolute_percentage_error: 57.3444
# Epoch 34/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 7.3418 - mean_absolute_percentage_error: 18.8564 - val_loss: 9.8216 - val_mean_absolute_percentage_error: 50.3797
# Epoch 35/50
# 11008/11008 [==============================] - 38s 3ms/sample - loss: 8.1063 - mean_absolute_percentage_error: 21.0972 - val_loss: 10.9858 - val_mean_absolute_percentage_error: 59.8240
# Epoch 36/50
# 11008/11008 [==============================] - 39s 4ms/sample - loss: 7.7318 - mean_absolute_percentage_error: 19.8603 - val_loss: 9.9434 - val_mean_absolute_percentage_error: 50.7134
# Epoch 37/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 7.5002 - mean_absolute_percentage_error: 19.2750 - val_loss: 10.8662 - val_mean_absolute_percentage_error: 59.1113
# Epoch 38/50
# 11008/11008 [==============================] - 38s 3ms/sample - loss: 7.4761 - mean_absolute_percentage_error: 19.3326 - val_loss: 10.1049 - val_mean_absolute_percentage_error: 52.9628
# Epoch 39/50
# 11008/11008 [==============================] - 39s 4ms/sample - loss: 10.9165 - mean_absolute_percentage_error: 30.3155 - val_loss: 12.0317 - val_mean_absolute_percentage_error: 65.5421
# Epoch 40/50
# 11008/11008 [==============================] - 37s 3ms/sample - loss: 15.8282 - mean_absolute_percentage_error: 47.1175 - val_loss: 13.6756 - val_mean_absolute_percentage_error: 76.1736
# Epoch 41/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 13.3687 - mean_absolute_percentage_error: 39.1616 - val_loss: 12.3124 - val_mean_absolute_percentage_error: 64.6231
# Epoch 42/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 11.5325 - mean_absolute_percentage_error: 32.7624 - val_loss: 12.3044 - val_mean_absolute_percentage_error: 67.2803
# Epoch 43/50
# 11008/11008 [==============================] - 33s 3ms/sample - loss: 10.3826 - mean_absolute_percentage_error: 28.6042 - val_loss: 11.3220 - val_mean_absolute_percentage_error: 60.0164
# Epoch 44/50
# 11008/11008 [==============================] - 34s 3ms/sample - loss: 9.7520 - mean_absolute_percentage_error: 26.6225 - val_loss: 12.0688 - val_mean_absolute_percentage_error: 65.8617
# Epoch 45/50
# 11008/11008 [==============================] - 36s 3ms/sample - loss: 9.2962 - mean_absolute_percentage_error: 25.3140 - val_loss: 10.9932 - val_mean_absolute_percentage_error: 56.9395
# Epoch 46/50
#  - ETA: 15s - loss: 8.9641 - mean_absolute_percentage_error: 23.8836
# Epoch 47/50
# 11008/11008 [==============================] - 33s 3ms/sample - loss: 8.6117 - mean_absolute_percentage_error: 23.1294 - val_loss: 12.4974 - val_mean_absolute_percentage_error: 69.3283
# Epoch 48/50
#  - ETA: 9s - loss: 8.3330 - mean_absolute_percentage_error: 22.4074
# Epoch 49/50
# 11008/11008 [==============================] - 35s 3ms/sample - loss: 8.0770 - mean_absolute_percentage_error: 21.7182 - val_loss: 12.1513 - val_mean_absolute_percentage_error: 66.2576
# Epoch 50/50
#  - ETA: 24s - loss: 8.4167 - mean_absolute_percentage_error: 22.8872

# %%
import matplotlib.pyplot as plt
result_dir = "D:/python_enviroments/Tensorflow_New_Enviroment/paper/论文实验部分/Result/"
file_name = "C attention, windowed and with time decay"
import matplotlib.pyplot as plt
# 连续化的对比图
final_data = main_dataset.final_data(para.validate_num)
real = final_data[para.train_size:].T[1].T
predict = list()
for index_var in range(para.validate_num):
    y = autoEncoder.predict(x=np.reshape(final_data[para.predict_size*index_var:para.predict_size*index_var+para.train_size],(-1,para.train_size,para.features)))
    y = np.reshape(y,(-1,))
    predict.append(y)
predict = np.reshape(np.array(predict),(-1,))
print(get_correlation(predict,real))
plt.plot(np.arange(0,len(predict)),predict,linewidth= 1,color = 'r', marker = '^',markersize=1)
plt.plot(np.arange(0,len(real)),real*data_std+data_mean,linewidth= 1,color = 'b', marker = 'o',markersize=1)
plt.xlabel('hour')
plt.ylabel('PM2.5')
plt.legend(['predict','real'])
# plt.savefig(result_dir+str(para.node_size)+ file_name+' prediction.png')
# Out:
# [[1.         0.61617317]
#  [0.61617317 1.        ]]

# %%
# 设置checkpoint  
plt.plot(np.arange(0,len(autoEncoder.history.history['loss'])),autoEncoder.history.history['loss'],marker = 'o',linewidth = 1,markersize = 4)
plt.plot(np.arange(0,len(autoEncoder.history.history['val_loss'])),autoEncoder.history.history['val_loss'],marker = '^', linewidth = 1,markersize = 4)
plt.xlabel('epochs')
plt.ylabel('Mae')
plt.legend(['train', 'test'])
# plt.savefig(result_dir+str(para.node_size)+ file_name+' loss.png')
